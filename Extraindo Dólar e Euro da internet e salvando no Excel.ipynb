# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.1.3-py3-none-any.whl (968 kB)
# Collecting trio~=0.17
#   Downloading trio-0.20.0-py3-none-any.whl (359 kB)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\valdi\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: sortedcontainers in c:\users\valdi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\valdi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: idna in c:\users\valdi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: sniffio in c:\users\valdi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\valdi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\valdi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\users\valdi\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\valdi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\valdi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\valdi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\valdi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\valdi\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.13.0 outcome-1.1.0 selenium-4.1.3 trio-0.20.0 trio-websocket-0.9.2 wsproto-1.1.0

# %%
#https://chromedriver.chromium.org/downloads


from selenium import webdriver

abrirNavegador = webdriver.Chrome()

abrirNavegador.get("https://www.google.com.br/")

# %%
#Abrindo o Google e capturando o valor do dolar

from selenium import webdriver as opcoes_selenium_aula
from selenium.webdriver.common.keys import Keys
import pyautogui as tempoPausaComputador
#Importando o By
from selenium.webdriver.common.by import By

meuNavegador = opcoes_selenium_aula.Chrome()
meuNavegador.get("https://www.google.com.br/")

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

#Procura o campo nome que está com que
#Depois que encontrar digita Dolar Hoje
meuNavegador.find_element(By.NAME, "q").send_keys("Dolar hoje")

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)
 
#Retorna para o campo nome q
meuNavegador.find_element(By.NAME, "q").send_keys(Keys.RETURN)
 
#Aguarda 4 segundos
tempoPausaComputador.sleep(4)
 
valorDolarPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text
 
print(valorDolarPeloGoogle)
# Out:
# 4,74

# %%
#Abrindo o Google e capturando o valor do dolar

from selenium import webdriver as opcoes_selenium_aula
from selenium.webdriver.common.keys import Keys
import pyautogui as tempoPausaComputador
#Importando o By
from selenium.webdriver.common.by import By

meuNavegador = opcoes_selenium_aula.Chrome()
meuNavegador.get("https://www.google.com.br/")

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

#Procura o campo nome que está com que
#Depois que encontrar digita Dolar Hoje
meuNavegador.find_element(By.NAME, "q").send_keys("Dolar hoje")

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

#Retorna para o campo nome q
meuNavegador.find_element(By.NAME, "q").send_keys(Keys.RETURN)

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

valorDolarPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#----------------------------------------------------------------------------------

#Aguarda 2 segundos
tempoPausaComputador.sleep(2)

#Procura o campo nome que está com que
#Depois que encontrar digita Dolar Hoje
meuNavegador.find_element(By.NAME, "q").send_keys("")

#Aguarda 2 segundos
tempoPausaComputador.sleep(4)

#Estamos usando a Pyautogui para apertar o Tab
tempoPausaComputador.press('tab')

#Aguarda 2 segundos
tempoPausaComputador.sleep(4)

#Estamos usando a Pyautogui para apertar o Enter
tempoPausaComputador.press('enter')

#Aguarda 2 segundos
tempoPausaComputador.sleep(4)

#Procura o campo nome que está com que
#Depois que encontrar digita Euro
meuNavegador.find_element(By.NAME, "q").send_keys("Euro")

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

#Retorna para o campo nome q
meuNavegador.find_element(By.NAME, "q").send_keys(Keys.RETURN)


#Aguarda 2 segundos
tempoPausaComputador.sleep(2)

valorEuroPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text


print("Dolar: " + valorDolarPeloGoogle)
print("Euro: " + valorEuroPeloGoogle)
# Out:
# Dolar: 4,74
# Euro: 5,29

# %%
#Biblioteca para arquivo excel
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in c:\users\valdi\anaconda3\lib\site-packages (3.0.1)

# %%
import xlsxwriter
import os

nomeCaminhoArquivo = 'C:\\Users\\valdi\\Documents\\CURSOS\\RPA Python\\Dolar e Euro Google.xlsx'
planilhaCriada = xlsxwriter.Workbook(nomeCaminhoArquivo)
sheet1 = planilhaCriada.add_worksheet() #Cria uma nova planilha em branco com o nome Sheet1

sheet1.write("A1", "Nome")
sheet1.write("B1", "Idade")
sheet1.write("A2", "Amanda")
sheet1.write("B2", 28)
sheet1.write("A3", "Roberto")
sheet1.write("B3", 25)

planilhaCriada.close()

os.startfile(nomeCaminhoArquivo)

# %%
#Abrindo o Google e capturando o valor do dolar

from selenium import webdriver as opcoes_selenium_aula
from selenium.webdriver.common.keys import Keys
import pyautogui as tempoPausaComputador
#Importando o By
from selenium.webdriver.common.by import By

meuNavegador = opcoes_selenium_aula.Chrome()
meuNavegador.get("https://www.google.com.br/")

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

#Procura o campo nome que está com que
#Depois que encontrar digita Dolar Hoje
meuNavegador.find_element(By.NAME, "q").send_keys("Dolar hoje")

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

#Retorna para o campo nome q
meuNavegador.find_element(By.NAME, "q").send_keys(Keys.RETURN)

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

valorDolarPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#----------------------------------------------------------------------------------

#Aguarda 2 segundos
tempoPausaComputador.sleep(2)

#Procura o campo nome que está com que
#Depois que encontrar digita Dolar Hoje
meuNavegador.find_element(By.NAME, "q").send_keys("")

#Aguarda 2 segundos
tempoPausaComputador.sleep(4)

#Estamos usando a Pyautogui para apertar o Tab
tempoPausaComputador.press('tab')

#Aguarda 2 segundos
tempoPausaComputador.sleep(4)

#Estamos usando a Pyautogui para apertar o Enter
tempoPausaComputador.press('enter')

#Aguarda 2 segundos
tempoPausaComputador.sleep(4)

#Procura o campo nome que está com que
#Depois que encontrar digita Euro
meuNavegador.find_element(By.NAME, "q").send_keys("Euro")

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

#Retorna para o campo nome q
meuNavegador.find_element(By.NAME, "q").send_keys(Keys.RETURN)


#Aguarda 2 segundos
tempoPausaComputador.sleep(2)

valorEuroPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#Aguarda 4 segundos
tempoPausaComputador.sleep(4)

#-------------------------------------------------------------------------

nomeCaminhoArquivo = 'C:\\Users\\valdi\\Documents\\CURSOS\\RPA Python\\Dolar e Euro Google.xlsx'
planilhaCriada = xlsxwriter.Workbook(nomeCaminhoArquivo)
sheet1 = planilhaCriada.add_worksheet() #Cria uma nova planilha em branco com o nome Sheet1

#Aguarda 6 segundos
tempoPausaComputador.sleep(6)

sheet1.write("A1", "Dolar")
sheet1.write("B1", "Euro")
sheet1.write("A2", valorDolarPeloGoogle)
sheet1.write("B2", valorEuroPeloGoogle)

#Aguarda 2 segundos
tempoPausaComputador.sleep(2)

planilhaCriada.close()

os.startfile(nomeCaminhoArquivo)

print("Dolar e Euro extraido com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1576/3563366534.py in <module>
#      78
#      79 #Aguarda 6 segundos
# ---> 80 tempoPausaComputador.sleep(6)
#      81
#      82 sheet1.write("A1", "Dolar")
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in sleep(seconds)
#    1792
#    1793 def sleep(seconds):
# -> 1794     time.sleep(seconds)
#    1795
#    1796
#
# KeyboardInterrupt:
